# %%
import pandas as pd
import numpy as np

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs=zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
cities = []
for coordinate in  coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 744

# %%
import requests
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cidreira
# Processing Record 2 of Set 1 | victoria
# Processing Record 3 of Set 1 | mar del plata
# Processing Record 4 of Set 1 | puerto ayora
# Processing Record 5 of Set 1 | nikolskoye
# Processing Record 6 of Set 1 | polson
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | saint george
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | dingle
# Processing Record 12 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 1 | portland
# Processing Record 14 of Set 1 | rawannawi
# City not found. Skipping...
# Processing Record 15 of Set 1 | esperance
# Processing Record 16 of Set 1 | calabozo
# Processing Record 17 of Set 1 | cape town
# Processing Record 18 of Set 1 | necochea
# Processing Record 19 of Set 1 | margate
# Processing Record 20 of Set 1 | lokomotivnyy
# Processing Record 21 of Set 1 | sabang
# Processing Record 22 of Set 1 | springdale
# Processing Record 23 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | ponta do sol
# Processing Record 26 of Set 1 | lebu
# Processing Record 27 of Set 1 | burica
# City not found. Skipping...
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | fort frances
# Processing Record 30 of Set 1 | progreso
# Processing Record 31 of Set 1 | uporovo
# Processing Record 32 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 1 | mecca
# Processing Record 34 of Set 1 | castro
# Processing Record 35 of Set 1 | santa cruz
# Processing Record 36 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 37 of Set 1 | upernavik
# Processing Record 38 of Set 1 | kahului
# Processing Record 39 of Set 1 | tamandare
# Processing Record 40 of Set 1 | qaanaaq
# Processing Record 41 of Set 1 | bor
# Processing Record 42 of Set 1 | port-gentil
# Processing Record 43 of Set 1 | hermanus
# Processing Record 44 of Set 1 | pevek
# Processing Record 45 of Set 1 | santiago del estero
# Processing Record 46 of Set 1 | tuatapere
# Processing Record 47 of Set 1 | busselton
# Processing Record 48 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 49 of Set 1 | hualmay
# Processing Record 50 of Set 1 | bethel
# Processing Record 1 of Set 2 | ahipara
# Processing Record 2 of Set 2 | luderitz
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | rocha
# Processing Record 5 of Set 2 | bathsheba
# Processing Record 6 of Set 2 | sao filipe
# Processing Record 7 of Set 2 | dikson
# Processing Record 8 of Set 2 | kavieng
# Processing Record 9 of Set 2 | meulaboh
# Processing Record 10 of Set 2 | yellowknife
# Processing Record 11 of Set 2 | codrington
# Processing Record 12 of Set 2 | arraial do cabo
# Processing Record 13 of Set 2 | lima
# Processing Record 14 of Set 2 | jalu
# Processing Record 15 of Set 2 | kande
# Processing Record 16 of Set 2 | rio grande
# Processing Record 17 of Set 2 | banmo
# City not found. Skipping...
# Processing Record 18 of Set 2 | mumford
# Processing Record 19 of Set 2 | chama
# Processing Record 20 of Set 2 | sechura
# Processing Record 21 of Set 2 | salalah
# Processing Record 22 of Set 2 | saldanha
# Processing Record 23 of Set 2 | sampit
# Processing Record 24 of Set 2 | vaini
# Processing Record 25 of Set 2 | cedar city
# Processing Record 26 of Set 2 | lasa
# Processing Record 27 of Set 2 | pagman
# City not found. Skipping...
# Processing Record 28 of Set 2 | ushuaia
# Processing Record 29 of Set 2 | khatanga
# Processing Record 30 of Set 2 | skierniewice
# Processing Record 31 of Set 2 | hobart
# Processing Record 32 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 2 | la rioja
# Processing Record 34 of Set 2 | bereda
# Processing Record 35 of Set 2 | mahebourg
# Processing Record 36 of Set 2 | salekhard
# Processing Record 37 of Set 2 | rorvik
# Processing Record 38 of Set 2 | alice springs
# Processing Record 39 of Set 2 | dourbali
# Processing Record 40 of Set 2 | punta arenas
# Processing Record 41 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 2 | senneterre
# Processing Record 45 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 2 | pangnirtung
# Processing Record 47 of Set 2 | lagoa
# Processing Record 48 of Set 2 | smithers
# Processing Record 49 of Set 2 | bluff
# Processing Record 50 of Set 2 | solnechnyy
# Processing Record 1 of Set 3 | klaksvik
# Processing Record 2 of Set 3 | hithadhoo
# Processing Record 3 of Set 3 | thompson
# Processing Record 4 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 3 | longyearbyen
# Processing Record 6 of Set 3 | caborca
# Processing Record 7 of Set 3 | bonthe
# Processing Record 8 of Set 3 | kumluca
# Processing Record 9 of Set 3 | trat
# Processing Record 10 of Set 3 | buon me thuot
# City not found. Skipping...
# Processing Record 11 of Set 3 | rawson
# Processing Record 12 of Set 3 | tsivilsk
# Processing Record 13 of Set 3 | imbituba
# Processing Record 14 of Set 3 | atuona
# Processing Record 15 of Set 3 | avera
# Processing Record 16 of Set 3 | nicolas bravo
# Processing Record 17 of Set 3 | broome
# Processing Record 18 of Set 3 | mackenzie
# Processing Record 19 of Set 3 | chokurdakh
# Processing Record 20 of Set 3 | shasta lake
# Processing Record 21 of Set 3 | padang
# Processing Record 22 of Set 3 | ayan
# Processing Record 23 of Set 3 | sistranda
# Processing Record 24 of Set 3 | te anau
# Processing Record 25 of Set 3 | slobidka
# Processing Record 26 of Set 3 | georgetown
# Processing Record 27 of Set 3 | luncavita
# Processing Record 28 of Set 3 | avarua
# Processing Record 29 of Set 3 | kruisfontein
# Processing Record 30 of Set 3 | sahy
# Processing Record 31 of Set 3 | hokitika
# Processing Record 32 of Set 3 | catumbela
# Processing Record 33 of Set 3 | ketchikan
# Processing Record 34 of Set 3 | tuktoyaktuk
# Processing Record 35 of Set 3 | xinzhi
# Processing Record 36 of Set 3 | lata
# Processing Record 37 of Set 3 | rikitea
# Processing Record 38 of Set 3 | buraydah
# Processing Record 39 of Set 3 | asyut
# Processing Record 40 of Set 3 | aykhal
# Processing Record 41 of Set 3 | bengkulu
# Processing Record 42 of Set 3 | la paz
# Processing Record 43 of Set 3 | ribeira grande
# Processing Record 44 of Set 3 | port alfred
# Processing Record 45 of Set 3 | kargat
# Processing Record 46 of Set 3 | ilulissat
# Processing Record 47 of Set 3 | willmar
# Processing Record 48 of Set 3 | malakal
# Processing Record 49 of Set 3 | fairbanks
# Processing Record 50 of Set 3 | ouadda
# Processing Record 1 of Set 4 | egvekinot
# Processing Record 2 of Set 4 | derzhavinsk
# Processing Record 3 of Set 4 | olafsvik
# Processing Record 4 of Set 4 | gusinoye ozero
# Processing Record 5 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 4 | bredasdorp
# Processing Record 9 of Set 4 | sorong
# Processing Record 10 of Set 4 | moose factory
# Processing Record 11 of Set 4 | aklavik
# Processing Record 12 of Set 4 | maridi
# Processing Record 13 of Set 4 | zhigansk
# Processing Record 14 of Set 4 | port lincoln
# Processing Record 15 of Set 4 | san felipe
# Processing Record 16 of Set 4 | flinders
# Processing Record 17 of Set 4 | tiznit
# Processing Record 18 of Set 4 | tiksi
# Processing Record 19 of Set 4 | nsoko
# Processing Record 20 of Set 4 | broken hill
# Processing Record 21 of Set 4 | ostrovnoy
# Processing Record 22 of Set 4 | east london
# Processing Record 23 of Set 4 | thinadhoo
# Processing Record 24 of Set 4 | savannah bight
# Processing Record 25 of Set 4 | caravelas
# Processing Record 26 of Set 4 | coos bay
# Processing Record 27 of Set 4 | barrow
# Processing Record 28 of Set 4 | coihaique
# Processing Record 29 of Set 4 | husavik
# Processing Record 30 of Set 4 | rybnaya sloboda
# Processing Record 31 of Set 4 | atocha
# Processing Record 32 of Set 4 | megion
# Processing Record 33 of Set 4 | yekaterinoslavka
# Processing Record 34 of Set 4 | nuuk
# Processing Record 35 of Set 4 | ola
# Processing Record 36 of Set 4 | buala
# Processing Record 37 of Set 4 | ferndale
# Processing Record 38 of Set 4 | tasiilaq
# Processing Record 39 of Set 4 | gat
# Processing Record 40 of Set 4 | indiana
# Processing Record 41 of Set 4 | kontagora
# Processing Record 42 of Set 4 | yanji
# Processing Record 43 of Set 4 | fengcheng
# Processing Record 44 of Set 4 | hamilton
# Processing Record 45 of Set 4 | carnarvon
# Processing Record 46 of Set 4 | hasaki
# Processing Record 47 of Set 4 | vardo
# Processing Record 48 of Set 4 | warrnambool
# Processing Record 49 of Set 4 | port hardy
# Processing Record 50 of Set 4 | lavrentiya
# Processing Record 1 of Set 5 | nadapuram
# Processing Record 2 of Set 5 | muros
# Processing Record 3 of Set 5 | baglung
# Processing Record 4 of Set 5 | mount isa
# Processing Record 5 of Set 5 | axim
# Processing Record 6 of Set 5 | saskylakh
# Processing Record 7 of Set 5 | alofi
# Processing Record 8 of Set 5 | itarema
# Processing Record 9 of Set 5 | araouane
# Processing Record 10 of Set 5 | okhotsk
# Processing Record 11 of Set 5 | plettenberg bay
# Processing Record 12 of Set 5 | beloha
# Processing Record 13 of Set 5 | mahaicony
# City not found. Skipping...
# Processing Record 14 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 15 of Set 5 | port elizabeth
# Processing Record 16 of Set 5 | natchez
# Processing Record 17 of Set 5 | san patricio
# Processing Record 18 of Set 5 | ponta delgada
# Processing Record 19 of Set 5 | fortuna
# Processing Record 20 of Set 5 | ust-tsilma
# Processing Record 21 of Set 5 | sibu
# Processing Record 22 of Set 5 | dwarka
# Processing Record 23 of Set 5 | norman wells
# Processing Record 24 of Set 5 | pozo colorado
# Processing Record 25 of Set 5 | iqaluit
# Processing Record 26 of Set 5 | quimper
# Processing Record 27 of Set 5 | gillette
# Processing Record 28 of Set 5 | hofn
# Processing Record 29 of Set 5 | poum
# Processing Record 30 of Set 5 | harlingen
# Processing Record 31 of Set 5 | severomuysk
# Processing Record 32 of Set 5 | bambous virieux
# Processing Record 33 of Set 5 | chuy
# Processing Record 34 of Set 5 | sungairaya
# Processing Record 35 of Set 5 | puerto penasco
# Processing Record 36 of Set 5 | christchurch
# Processing Record 37 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 5 | mamlyutka
# Processing Record 39 of Set 5 | charters towers
# Processing Record 40 of Set 5 | copacabana
# Processing Record 41 of Set 5 | mareeba
# Processing Record 42 of Set 5 | mumbwa
# Processing Record 43 of Set 5 | baykit
# Processing Record 44 of Set 5 | panzhihua
# Processing Record 45 of Set 5 | cherskiy
# Processing Record 46 of Set 5 | namibe
# Processing Record 47 of Set 5 | kegayli
# City not found. Skipping...
# Processing Record 48 of Set 5 | dinga
# Processing Record 49 of Set 5 | biak
# Processing Record 50 of Set 5 | gamba
# Processing Record 1 of Set 6 | tanah merah
# Processing Record 2 of Set 6 | san isidro
# Processing Record 3 of Set 6 | tilichiki
# Processing Record 4 of Set 6 | college
# Processing Record 5 of Set 6 | asekeyevo
# Processing Record 6 of Set 6 | brigantine
# Processing Record 7 of Set 6 | srednekolymsk
# Processing Record 8 of Set 6 | doha
# Processing Record 9 of Set 6 | sioux lookout
# Processing Record 10 of Set 6 | aleksandrovskoye
# Processing Record 11 of Set 6 | mizdah
# Processing Record 12 of Set 6 | adrar
# Processing Record 13 of Set 6 | aginskoye
# Processing Record 14 of Set 6 | bambanglipuro
# Processing Record 15 of Set 6 | new norfolk
# Processing Record 16 of Set 6 | natal
# Processing Record 17 of Set 6 | lensk
# Processing Record 18 of Set 6 | mount gambier
# Processing Record 19 of Set 6 | gotsu
# Processing Record 20 of Set 6 | saint-philippe
# Processing Record 21 of Set 6 | provideniya
# Processing Record 22 of Set 6 | anadyr
# Processing Record 23 of Set 6 | butaritari
# Processing Record 24 of Set 6 | amzya
# Processing Record 25 of Set 6 | marzuq
# Processing Record 26 of Set 6 | coevorden
# Processing Record 27 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 6 | andevoranto
# City not found. Skipping...
# Processing Record 29 of Set 6 | andra
# Processing Record 30 of Set 6 | mezen
# Processing Record 31 of Set 6 | airai
# Processing Record 32 of Set 6 | mastic beach
# Processing Record 33 of Set 6 | road town
# Processing Record 34 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 35 of Set 6 | evensk
# Processing Record 36 of Set 6 | katsuura
# Processing Record 37 of Set 6 | anamur
# Processing Record 38 of Set 6 | havelock
# Processing Record 39 of Set 6 | soria
# Processing Record 40 of Set 6 | sur
# Processing Record 41 of Set 6 | kaitangata
# Processing Record 42 of Set 6 | zabid
# Processing Record 43 of Set 6 | port shepstone
# Processing Record 44 of Set 6 | pisco
# Processing Record 45 of Set 6 | ust-maya
# Processing Record 46 of Set 6 | tymovskoye
# Processing Record 47 of Set 6 | brae
# Processing Record 48 of Set 6 | paamiut
# Processing Record 49 of Set 6 | narsaq
# Processing Record 50 of Set 6 | chapais
# Processing Record 1 of Set 7 | bahadurgarh
# Processing Record 2 of Set 7 | mayo
# Processing Record 3 of Set 7 | alta floresta
# Processing Record 4 of Set 7 | abu kamal
# Processing Record 5 of Set 7 | upata
# Processing Record 6 of Set 7 | arman
# Processing Record 7 of Set 7 | rio gallegos
# Processing Record 8 of Set 7 | benidorm
# Processing Record 9 of Set 7 | severo-kurilsk
# Processing Record 10 of Set 7 | ahuimanu
# Processing Record 11 of Set 7 | mugango
# Processing Record 12 of Set 7 | nome
# Processing Record 13 of Set 7 | inyonga
# Processing Record 14 of Set 7 | floro
# Processing Record 15 of Set 7 | mogadishu
# Processing Record 16 of Set 7 | ternate
# Processing Record 17 of Set 7 | kadaura
# Processing Record 18 of Set 7 | mattawa
# Processing Record 19 of Set 7 | cabo san lucas
# Processing Record 20 of Set 7 | ilhabela
# Processing Record 21 of Set 7 | neokhorion
# Processing Record 22 of Set 7 | sakaiminato
# Processing Record 23 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 7 | kodiak
# Processing Record 25 of Set 7 | zvishavane
# Processing Record 26 of Set 7 | grand gaube
# Processing Record 27 of Set 7 | constitucion
# Processing Record 28 of Set 7 | ligatne
# Processing Record 29 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 30 of Set 7 | ust-nera
# Processing Record 31 of Set 7 | kodinsk
# Processing Record 32 of Set 7 | sarkand
# Processing Record 33 of Set 7 | kununurra
# Processing Record 34 of Set 7 | caceres
# Processing Record 35 of Set 7 | noumea
# Processing Record 36 of Set 7 | saint anthony
# Processing Record 37 of Set 7 | dudinka
# Processing Record 38 of Set 7 | bilma
# Processing Record 39 of Set 7 | monticello
# Processing Record 40 of Set 7 | daru
# Processing Record 41 of Set 7 | nauta
# Processing Record 42 of Set 7 | kloulklubed
# Processing Record 43 of Set 7 | samarai
# Processing Record 44 of Set 7 | naron
# Processing Record 45 of Set 7 | tartki
# City not found. Skipping...
# Processing Record 46 of Set 7 | yar-sale
# Processing Record 47 of Set 7 | yefira
# City not found. Skipping...
# Processing Record 48 of Set 7 | dongkan
# Processing Record 49 of Set 7 | kavaratti
# Processing Record 50 of Set 7 | vuktyl
# Processing Record 1 of Set 8 | cabedelo
# Processing Record 2 of Set 8 | nanortalik
# Processing Record 3 of Set 8 | muravlenko
# Processing Record 4 of Set 8 | akdepe
# Processing Record 5 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 8 | west plains
# Processing Record 7 of Set 8 | alugan
# Processing Record 8 of Set 8 | santa isabel
# Processing Record 9 of Set 8 | vestmannaeyjar
# Processing Record 10 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 12 of Set 8 | dori
# Processing Record 13 of Set 8 | vanavara
# Processing Record 14 of Set 8 | nizhniy odes
# Processing Record 15 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 16 of Set 8 | inhambane
# Processing Record 17 of Set 8 | hay river
# Processing Record 18 of Set 8 | leningradskiy
# Processing Record 19 of Set 8 | livingstonia
# Processing Record 20 of Set 8 | vao
# Processing Record 21 of Set 8 | staryy nadym
# Processing Record 22 of Set 8 | biryusinsk
# Processing Record 23 of Set 8 | ossora
# Processing Record 24 of Set 8 | souillac
# Processing Record 25 of Set 8 | tezu
# Processing Record 26 of Set 8 | tougan
# Processing Record 27 of Set 8 | roma
# Processing Record 28 of Set 8 | inuvik
# Processing Record 29 of Set 8 | poronaysk
# Processing Record 30 of Set 8 | south shields
# Processing Record 31 of Set 8 | nenjiang
# Processing Record 32 of Set 8 | prachuap khiri khan
# Processing Record 33 of Set 8 | seoul
# Processing Record 34 of Set 8 | acarau
# Processing Record 35 of Set 8 | tocopilla
# Processing Record 36 of Set 8 | rabaul
# Processing Record 37 of Set 8 | sanchez
# Processing Record 38 of Set 8 | sitka
# Processing Record 39 of Set 8 | fereydunshahr
# Processing Record 40 of Set 8 | laguna
# Processing Record 41 of Set 8 | daura
# Processing Record 42 of Set 8 | guerrero negro
# Processing Record 43 of Set 8 | rengo
# Processing Record 44 of Set 8 | faanui
# Processing Record 45 of Set 8 | diego de almagro
# Processing Record 46 of Set 8 | atbasar
# Processing Record 47 of Set 8 | colac
# Processing Record 48 of Set 8 | sao francisco
# Processing Record 49 of Set 8 | talnakh
# Processing Record 50 of Set 8 | cruzeiro do sul
# Processing Record 1 of Set 9 | sambava
# Processing Record 2 of Set 9 | dunedin
# Processing Record 3 of Set 9 | aksu
# Processing Record 4 of Set 9 | ancud
# Processing Record 5 of Set 9 | cockburn town
# Processing Record 6 of Set 9 | argir
# Processing Record 7 of Set 9 | waipawa
# Processing Record 8 of Set 9 | omboue
# Processing Record 9 of Set 9 | uray
# Processing Record 10 of Set 9 | isangel
# Processing Record 11 of Set 9 | bubaque
# Processing Record 12 of Set 9 | dahra
# Processing Record 13 of Set 9 | namatanai
# Processing Record 14 of Set 9 | khowst
# Processing Record 15 of Set 9 | faya
# Processing Record 16 of Set 9 | cape canaveral
# Processing Record 17 of Set 9 | beian
# Processing Record 18 of Set 9 | kousseri
# Processing Record 19 of Set 9 | ca mau
# Processing Record 20 of Set 9 | santa rosa
# Processing Record 21 of Set 9 | slave lake
# Processing Record 22 of Set 9 | shingu
# Processing Record 23 of Set 9 | mountain home
# Processing Record 24 of Set 9 | dilla
# Processing Record 25 of Set 9 | rapid city
# Processing Record 26 of Set 9 | asau
# Processing Record 27 of Set 9 | dryden
# Processing Record 28 of Set 9 | umm lajj
# Processing Record 29 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 9 | marfino
# Processing Record 31 of Set 9 | concordia
# Processing Record 32 of Set 9 | severo-yeniseyskiy
# Processing Record 33 of Set 9 | sahaswan
# Processing Record 34 of Set 9 | altay
# Processing Record 35 of Set 9 | kimbe
# Processing Record 36 of Set 9 | northam
# Processing Record 37 of Set 9 | limeira
# Processing Record 38 of Set 9 | itarsi
# Processing Record 39 of Set 9 | stykkisholmur
# Processing Record 40 of Set 9 | myitkyina
# Processing Record 41 of Set 9 | harda
# Processing Record 42 of Set 9 | cowra
# Processing Record 43 of Set 9 | beringovskiy
# Processing Record 44 of Set 9 | kapoeta
# Processing Record 45 of Set 9 | camacupa
# Processing Record 46 of Set 9 | aktash
# Processing Record 47 of Set 9 | znamenskoye
# Processing Record 48 of Set 9 | homer
# Processing Record 49 of Set 9 | merauke
# Processing Record 50 of Set 9 | matay
# Processing Record 1 of Set 10 | litoral del san juan
# City not found. Skipping...
# Processing Record 2 of Set 10 | chukhloma
# Processing Record 3 of Set 10 | bidor
# Processing Record 4 of Set 10 | moron
# Processing Record 5 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 6 of Set 10 | adre
# Processing Record 7 of Set 10 | comodoro rivadavia
# Processing Record 8 of Set 10 | palmer
# Processing Record 9 of Set 10 | kawalu
# Processing Record 10 of Set 10 | yulara
# Processing Record 11 of Set 10 | qandahar
# City not found. Skipping...
# Processing Record 12 of Set 10 | kawana waters
# City not found. Skipping...
# Processing Record 13 of Set 10 | bataipora
# Processing Record 14 of Set 10 | udomlya
# Processing Record 15 of Set 10 | saquarema
# Processing Record 16 of Set 10 | puerto narino
# Processing Record 17 of Set 10 | grindavik
# Processing Record 18 of Set 10 | pljevlja
# Processing Record 19 of Set 10 | nouadhibou
# Processing Record 20 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 21 of Set 10 | kerki
# City not found. Skipping...
# Processing Record 22 of Set 10 | kourou
# Processing Record 23 of Set 10 | port macquarie
# Processing Record 24 of Set 10 | lorengau
# Processing Record 25 of Set 10 | swan river
# Processing Record 26 of Set 10 | makakilo city
# Processing Record 27 of Set 10 | bardiyah
# Processing Record 28 of Set 10 | popesti
# Processing Record 29 of Set 10 | mocuba
# Processing Record 30 of Set 10 | suzu
# City not found. Skipping...
# Processing Record 31 of Set 10 | fontenay-le-comte
# Processing Record 32 of Set 10 | killybegs
# Processing Record 33 of Set 10 | vila franca do campo
# Processing Record 34 of Set 10 | sainte-thecle
# Processing Record 35 of Set 10 | sooke
# Processing Record 36 of Set 10 | almaznyy
# Processing Record 37 of Set 10 | san cristobal
# Processing Record 38 of Set 10 | cayenne
# Processing Record 39 of Set 10 | san vicente
# Processing Record 40 of Set 10 | kaeo
# Processing Record 41 of Set 10 | jabiru
# City not found. Skipping...
# Processing Record 42 of Set 10 | nabire
# Processing Record 43 of Set 10 | chabahar
# Processing Record 44 of Set 10 | del rio
# Processing Record 45 of Set 10 | komsomolskiy
# Processing Record 46 of Set 10 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 47 of Set 10 | seymchan
# Processing Record 48 of Set 10 | panjab
# Processing Record 49 of Set 10 | jarjis
# City not found. Skipping...
# Processing Record 50 of Set 10 | henties bay
# Processing Record 1 of Set 11 | geraldton
# Processing Record 2 of Set 11 | acapulco
# Processing Record 3 of Set 11 | desaguadero
# Processing Record 4 of Set 11 | hailar
# Processing Record 5 of Set 11 | siocon
# Processing Record 6 of Set 11 | bose
# Processing Record 7 of Set 11 | kudat
# Processing Record 8 of Set 11 | clyde river
# Processing Record 9 of Set 11 | lloro
# Processing Record 10 of Set 11 | dumas
# Processing Record 11 of Set 11 | aldan
# Processing Record 12 of Set 11 | moranbah
# Processing Record 13 of Set 11 | corvallis
# Processing Record 14 of Set 11 | belaya gora
# Processing Record 15 of Set 11 | kikwit
# Processing Record 16 of Set 11 | ergani
# Processing Record 17 of Set 11 | ucluelet
# Processing Record 18 of Set 11 | andenes
# Processing Record 19 of Set 11 | khash
# Processing Record 20 of Set 11 | bintulu
# Processing Record 21 of Set 11 | shimoda
# Processing Record 22 of Set 11 | yerbogachen
# Processing Record 23 of Set 11 | palenque
# Processing Record 24 of Set 11 | kostomuksha
# Processing Record 25 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 26 of Set 11 | maghama
# City not found. Skipping...
# Processing Record 27 of Set 11 | brentwood
# Processing Record 28 of Set 11 | yomitan
# City not found. Skipping...
# Processing Record 29 of Set 11 | krasnoselkup
# Processing Record 30 of Set 11 | mabaruma
# Processing Record 31 of Set 11 | terekli-mekteb
# Processing Record 32 of Set 11 | hambantota
# Processing Record 33 of Set 11 | mahibadhoo
# Processing Record 34 of Set 11 | sao joao da barra
# Processing Record 35 of Set 11 | nha trang
# Processing Record 36 of Set 11 | kabelvag
# Processing Record 37 of Set 11 | morganton
# Processing Record 38 of Set 11 | dombarovskiy
# Processing Record 39 of Set 11 | novomalorossiyskaya
# Processing Record 40 of Set 11 | luz
# Processing Record 41 of Set 11 | jacqueville
# Processing Record 42 of Set 11 | abu dhabi
# Processing Record 43 of Set 11 | ixtapa
# Processing Record 44 of Set 11 | groningen
# Processing Record 45 of Set 11 | matara
# Processing Record 46 of Set 11 | vanderhoof
# Processing Record 47 of Set 11 | shestakovo
# Processing Record 48 of Set 11 | bama
# Processing Record 49 of Set 11 | salinas
# Processing Record 50 of Set 11 | kalianget
# Processing Record 1 of Set 12 | saint-pierre
# Processing Record 2 of Set 12 | kattivakkam
# Processing Record 3 of Set 12 | sumbe
# Processing Record 4 of Set 12 | kaka
# Processing Record 5 of Set 12 | tevaitoa
# Processing Record 6 of Set 12 | kiunga
# Processing Record 7 of Set 12 | primorsk
# Processing Record 8 of Set 12 | mandalgovi
# Processing Record 9 of Set 12 | aleksandrov gay
# Processing Record 10 of Set 12 | two hills
# Processing Record 11 of Set 12 | fairmont
# Processing Record 12 of Set 12 | saint-vallier
# Processing Record 13 of Set 12 | tabarqah
# City not found. Skipping...
# Processing Record 14 of Set 12 | coahuayana
# Processing Record 15 of Set 12 | kropotkin
# Processing Record 16 of Set 12 | kanniyakumari
# Processing Record 17 of Set 12 | umtata
# Processing Record 18 of Set 12 | storslett
# Processing Record 19 of Set 12 | pingzhuang
# Processing Record 20 of Set 12 | sola
# Processing Record 21 of Set 12 | ambon
# Processing Record 22 of Set 12 | varhaug
# Processing Record 23 of Set 12 | fort nelson
# Processing Record 24 of Set 12 | lianran
# Processing Record 25 of Set 12 | wajid
# Processing Record 26 of Set 12 | manavalakurichi
# Processing Record 27 of Set 12 | tarakan
# Processing Record 28 of Set 12 | wanning
# Processing Record 29 of Set 12 | kasongo-lunda
# Processing Record 30 of Set 12 | urumqi
# Processing Record 31 of Set 12 | togur
# Processing Record 32 of Set 12 | zlatoustovsk
# City not found. Skipping...
# Processing Record 33 of Set 12 | redlands
# Processing Record 34 of Set 12 | bontang
# Processing Record 35 of Set 12 | plastun
# Processing Record 36 of Set 12 | nemuro
# Processing Record 37 of Set 12 | loukhi
# Processing Record 38 of Set 12 | skala fourkas
# Processing Record 39 of Set 12 | burgersdorp
# Processing Record 40 of Set 12 | sibiti
# Processing Record 41 of Set 12 | los llanos de aridane
# Processing Record 42 of Set 12 | bridgewater
# Processing Record 43 of Set 12 | oktyabrskiy
# Processing Record 44 of Set 12 | bahia honda
# Processing Record 45 of Set 12 | chittaurgarh
# Processing Record 46 of Set 12 | osorno
# Processing Record 47 of Set 12 | honningsvag
# Processing Record 48 of Set 12 | anshun
# Processing Record 49 of Set 12 | paungde
# Processing Record 50 of Set 12 | mae hong son
# Processing Record 1 of Set 13 | ardesen
# Processing Record 2 of Set 13 | baherden
# Processing Record 3 of Set 13 | iralaya
# Processing Record 4 of Set 13 | gazojak
# Processing Record 5 of Set 13 | nanakuli
# Processing Record 6 of Set 13 | pandhana
# Processing Record 7 of Set 13 | tenextatiloyan
# City not found. Skipping...
# Processing Record 8 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 13 | tarnogskiy gorodok
# Processing Record 10 of Set 13 | goure
# Processing Record 11 of Set 13 | amuntai
# Processing Record 12 of Set 13 | tambul
# City not found. Skipping...
# Processing Record 13 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 13 | maloy
# Processing Record 15 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 13 | eureka
# Processing Record 17 of Set 13 | urdzhar
# City not found. Skipping...
# Processing Record 18 of Set 13 | berezovka
# Processing Record 19 of Set 13 | sol-iletsk
# Processing Record 20 of Set 13 | torbay
# Processing Record 21 of Set 13 | pailon
# Processing Record 22 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 23 of Set 13 | san luis
# Processing Record 24 of Set 13 | solec kujawski
# Processing Record 25 of Set 13 | acari
# Processing Record 26 of Set 13 | ndola
# Processing Record 27 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 28 of Set 13 | lawton
# Processing Record 29 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 30 of Set 13 | guarapari
# Processing Record 31 of Set 13 | shieli
# Processing Record 32 of Set 13 | havre-saint-pierre
# Processing Record 33 of Set 13 | requena
# Processing Record 34 of Set 13 | bolotnoye
# Processing Record 35 of Set 13 | mongo
# Processing Record 36 of Set 13 | maldonado
# Processing Record 37 of Set 13 | adolfo lopez mateos
# Processing Record 38 of Set 13 | eirunepe
# Processing Record 39 of Set 13 | lazaro cardenas
# Processing Record 40 of Set 13 | raffadali
# Processing Record 41 of Set 13 | sao sebastiao
# Processing Record 42 of Set 13 | union de reyes
# Processing Record 43 of Set 13 | igrim
# Processing Record 44 of Set 13 | tharad
# Processing Record 45 of Set 13 | port augusta
# Processing Record 46 of Set 13 | okmulgee
# Processing Record 47 of Set 13 | helong
# Processing Record 48 of Set 13 | troitskoye
# Processing Record 49 of Set 13 | saint-leu
# Processing Record 50 of Set 13 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 14 | nganjuk
# Processing Record 2 of Set 14 | wufeng
# Processing Record 3 of Set 14 | iranshahr
# Processing Record 4 of Set 14 | zarubino
# Processing Record 5 of Set 14 | penalva
# Processing Record 6 of Set 14 | las vegas
# Processing Record 7 of Set 14 | roebourne
# Processing Record 8 of Set 14 | ligayan
# Processing Record 9 of Set 14 | amapa
# Processing Record 10 of Set 14 | garowe
# Processing Record 11 of Set 14 | barcelona
# Processing Record 12 of Set 14 | kisangani
# Processing Record 13 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 14 of Set 14 | tabou
# Processing Record 15 of Set 14 | florianopolis
# Processing Record 16 of Set 14 | novikovo
# Processing Record 17 of Set 14 | troitsko-pechorsk
# Processing Record 18 of Set 14 | bonavista
# Processing Record 19 of Set 14 | havoysund
# Processing Record 20 of Set 14 | pontes e lacerda
# Processing Record 21 of Set 14 | tazovskiy
# Processing Record 22 of Set 14 | honiara
# Processing Record 23 of Set 14 | poya
# Processing Record 24 of Set 14 | sanchor
# Processing Record 25 of Set 14 | muroto
# Processing Record 26 of Set 14 | udachnyy
# Processing Record 27 of Set 14 | sao miguel
# Processing Record 28 of Set 14 | iquique
# Processing Record 29 of Set 14 | metro
# Processing Record 30 of Set 14 | venkatagiri
# Processing Record 31 of Set 14 | novouzensk
# Processing Record 32 of Set 14 | palmas bellas
# Processing Record 33 of Set 14 | conguaco
# Processing Record 34 of Set 14 | mutare
# Processing Record 35 of Set 14 | ugoofaaru
# Processing Record 36 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 37 of Set 14 | kashi
# Processing Record 38 of Set 14 | aripuana
# Processing Record 39 of Set 14 | touros
# Processing Record 40 of Set 14 | bethanien
# Processing Record 41 of Set 14 | erie
# Processing Record 42 of Set 14 | savelugu
# Processing Record 43 of Set 14 | dimitrovgrad
# Processing Record 44 of Set 14 | matagami
# Processing Record 45 of Set 14 | russell
# Processing Record 46 of Set 14 | kuruman
# Processing Record 47 of Set 14 | madang
# Processing Record 48 of Set 14 | vila velha
# Processing Record 49 of Set 14 | shelburne
# Processing Record 50 of Set 14 | katherine
# Processing Record 1 of Set 15 | oistins
# Processing Record 2 of Set 15 | qasigiannguit
# Processing Record 3 of Set 15 | nara
# Processing Record 4 of Set 15 | siuna
# Processing Record 5 of Set 15 | tumpat
# Processing Record 6 of Set 15 | manggar
# Processing Record 7 of Set 15 | okakarara
# Processing Record 8 of Set 15 | cocorit
# Processing Record 9 of Set 15 | saint-medard-en-jalles
# Processing Record 10 of Set 15 | brodokalmak
# Processing Record 11 of Set 15 | kungurtug
# Processing Record 12 of Set 15 | ekhabi
# Processing Record 13 of Set 15 | port moresby
# Processing Record 14 of Set 15 | juneau
# Processing Record 15 of Set 15 | hanzhong
# Processing Record 16 of Set 15 | brokopondo
# Processing Record 17 of Set 15 | maniitsoq
# Processing Record 18 of Set 15 | karamea
# City not found. Skipping...
# Processing Record 19 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 20 of Set 15 | teya
# Processing Record 21 of Set 15 | oranjemund
# Processing Record 22 of Set 15 | atambua
# Processing Record 23 of Set 15 | buin
# Processing Record 24 of Set 15 | beroroha
# Processing Record 25 of Set 15 | burnie
# Processing Record 26 of Set 15 | oyem
# Processing Record 27 of Set 15 | alyangula
# Processing Record 28 of Set 15 | diamantino
# Processing Record 29 of Set 15 | mariahu
# Processing Record 30 of Set 15 | mahadday weyne
# City not found. Skipping...
# Processing Record 31 of Set 15 | gizo
# Processing Record 32 of Set 15 | maykain
# City not found. Skipping...
# Processing Record 33 of Set 15 | akureyri
# Processing Record 34 of Set 15 | loubomo
# Processing Record 35 of Set 15 | oparino
# Processing Record 36 of Set 15 | muzhi
# Processing Record 37 of Set 15 | buk
# Processing Record 38 of Set 15 | potosi
# Processing Record 39 of Set 15 | valmiera
# Processing Record 40 of Set 15 | bozoum
# Processing Record 41 of Set 15 | camacha
# Processing Record 42 of Set 15 | verkh-chebula
# Processing Record 43 of Set 15 | karangampel
# Processing Record 44 of Set 15 | niamey
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 678

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Cidreira -30.1811  -50.2056     78.76        69           1
# 1       Victoria  22.2855  114.1577     65.25        88         100
# 2  Mar Del Plata -38.0023  -57.5575     64.42        68          40
# 3   Puerto Ayora  -0.7393  -90.3518     87.76        84         100
# 4     Nikolskoye  59.7035   30.7861     34.72        96         100
# 5         Polson  47.6936 -114.1632     41.59        68          13
# 6        Mataura -46.1927  168.8643     50.49        92          92
# 7      Jamestown  42.0970  -79.2353     31.32        63         100
# 8   Saint George  37.1041 -113.5841     64.87        20           0
# 9           Hilo  19.7297 -155.0900     77.11        62          20
#
#    Wind Speed Country Current Description
# 0       18.14      BR           clear sky
# 1        8.01      HK     overcast clouds
# 2       18.41      AR    scattered clouds
# 3        4.00      EC     overcast clouds
# 4       12.12      RU                snow
# 5        1.57      US          few clouds
# 6        2.82      NZ     overcast clouds
# 7        9.22      US     overcast clouds
# 8        3.44      US           clear sky
# 9        4.61      US          few clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]

# %%
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Cidreira      BR -30.1811  -50.2056     78.76        69           1
# 1         Victoria      HK  22.2855  114.1577     65.25        88         100
# 2    Mar Del Plata      AR -38.0023  -57.5575     64.42        68          40
# 3     Puerto Ayora      EC  -0.7393  -90.3518     87.76        84         100
# 4       Nikolskoye      RU  59.7035   30.7861     34.72        96         100
# ..             ...     ...      ...       ...       ...       ...         ...
# 673         Bozoum      CF   6.3193   16.3799     74.46        20           5
# 674        Camacha      PT  33.0833  -16.3333     60.22        77          75
# 675  Verkh-Chebula      RU  56.0308   87.6218     -1.48        88           3
# 676    Karangampel      ID  -6.4622  108.4519     77.61        88         100
# 677         Niamey      NE  13.5137    2.1098     86.29         8           6
#
#      Wind Speed Current Description
# 0         18.14           clear sky
# 1          8.01     overcast clouds
# 2         18.41    scattered clouds
# 3          4.00     overcast clouds
# 4         12.12                snow
# ..          ...                 ...
# 673        3.38           clear sky
# 674       13.80       broken clouds
# 675       10.47           clear sky
# 676        7.02          light rain
# 677        2.30                dust
#
# [678 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPY_Database.csv"
city_data_df.to_csv(output_data_file)
